# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import matplotlib.patches as patches

# %%
df = pd.read_csv("benchmark_results_fixed_n.csv")

# %%
df
# Out:
#        Unnamed: 0                                fname1  \
# 0               0   network_n100_alpha0.3_beta0.01_0.gr
# 1               1   network_n100_alpha0.3_beta0.01_0.gr
# 2               2   network_n100_alpha0.3_beta0.01_0.gr
# 3               3   network_n100_alpha0.3_beta0.01_0.gr
# 4               4   network_n100_alpha0.3_beta0.01_0.gr
# ...           ...                                   ...
# 13651       13651  network_n100_alpha0.7_beta1.25_99.gr
# 13652       13652  network_n100_alpha0.7_beta1.25_99.gr
# 13653       13653  network_n100_alpha0.7_beta1.25_99.gr
# 13654       13654  network_n100_alpha0.7_beta1.25_99.gr
# 13655       13655  network_n100_alpha0.7_beta1.25_99.gr
#
#                                      fname2  nsteps1  nsteps2  alphas1  \
# 0       network_n100_alpha0.3_beta0.01_0.gr      100      100      0.3
# 1       network_n100_alpha0.3_beta0.01_6.gr      100      100      0.3
# 2      network_n100_alpha0.3_beta0.01_17.gr      100      100      0.3
# 3      network_n100_alpha0.3_beta0.01_48.gr      100      100      0.3
# 4      network_n100_alpha0.3_beta0.01_59.gr      100      100      0.3
# ...                                     ...      ...      ...      ...
# 13651  network_n100_alpha0.7_beta1.25_65.gr      100      100      0.7
# 13652  network_n100_alpha0.7_beta1.25_76.gr      100      100      0.7
# 13653  network_n100_alpha0.7_beta1.25_79.gr      100      100      0.7
# 13654  network_n100_alpha0.7_beta1.25_91.gr      100      100      0.7
# 13655  network_n100_alpha0.7_beta1.25_99.gr      100      100      0.7
#
#        alphas2  betas1  betas2  levels1  levels2  nnodes_network1  \
# 0          0.3    0.01    0.01       24       24              203
# 1          0.3    0.01    0.01       24       26              203
# 2          0.3    0.01    0.01       24       27              203
# 3          0.3    0.01    0.01       24       27              203
# 4          0.3    0.01    0.01       24       22              203
# ...        ...     ...     ...      ...      ...              ...
# 13651      0.7    1.25    1.25       73       73              203
# 13652      0.7    1.25    1.25       73       73              203
# 13653      0.7    1.25    1.25       73       73              203
# 13654      0.7    1.25    1.25       73       73              203
# 13655      0.7    1.25    1.25       73       73              203
#
#        nnodes_network2  nleaves_network1  nleaves_network2  \
# 0                  203                73                73
# 1                  203                73                73
# 2                  203                73                73
# 3                  203                73                73
# 4                  203                73                73
# ...                ...               ...               ...
# 13651              203                29                29
# 13652              203                29                29
# 13653              203                29                29
# 13654              203                29                29
# 13655              203                29                29
#
#        ntransfers_network1  ntransfers_network2  distance   runtime
# 0                       29                   29         0  0.002406
# 1                       29                   29       207  0.002741
# 2                       29                   29       188  0.004170
# 3                       29                   29       189  0.003138
# 4                       29                   29       187  0.002941
# ...                    ...                  ...       ...       ...
# 13651                   73                   73       239  0.002613
# 13652                   73                   73       255  0.002438
# 13653                   73                   73       242  0.002472
# 13654                   73                   73       233  0.002422
# 13655                   73                   73         0  0.003509
#
# [13656 rows x 19 columns]

# %%
data_per_alpha_beta = {}

# %%
for index, row in df.iterrows():
    if row.betas1!=row.betas2:
        continue
    alpha = row.alphas1
    beta = row.betas1
    if np.isnan(row.runtime):
        print("nan indeed")
        continue
    try:
        data_per_alpha_beta[(alpha,beta)].append(row.runtime)
    except KeyError:
        data_per_alpha_beta[(alpha,beta)] = [row.runtime]

# %%
import seaborn as sns

# %%
alphas = set([])
betas = set([])
for alpha,beta in data_per_alpha_beta.keys():
    alphas.add(alpha)
    betas.add(beta)

# %%
alphas = sorted(list(alphas))
betas = sorted(list(betas))

# %%
import numpy as np

# %%
data = np.zeros((len(alphas),len(betas)))

# %%
for k,alpha in enumerate(alphas):
    for l,beta in enumerate(betas):
        data[k,l] = np.mean([x for x in data_per_alpha_beta[(alpha,beta)] if not np.isnan(x)])

# %%
data = pd.DataFrame(data,columns=betas,index=alphas)
#rect = patches.Rectangle((0.01, 0.01), 3.98, 3.98, linewidth=1, edgecolor='r', facecolor='none', angle=0)
fig, ax = plt.subplots(figsize=(7,3.5))
sns.heatmap(data,cmap="Blues",annot=True,annot_kws={"fontsize": 11},cbar_kws={"label":"average computation time (seconds)"})
#plt.gca().add_patch(rect)
plt.xlabel("beta",fontsize=11)
plt.ylabel("alpha",fontsize=11)
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
print(plt.gca().get_xlim())
plt.savefig("alpha_beta_fixed_n.pdf",bbox_inches="tight")
# Out:
# (np.float64(4.0), np.float64(0.0))

# %%
data
# Out:
#          0.01      0.05      0.25      1.25
# 0.3  0.004356  0.004299  0.004240  0.004321
# 0.4  0.004311  0.004356  0.004454  0.004376
# 0.5  0.004583  0.004373  0.004416  0.004410
# 0.6  0.005086  0.004734  0.004458  0.004484
# 0.7  0.160613  0.011773  0.004654  0.004873

# %%
alphas
# Out:
# [0.3, 0.4, 0.5, 0.6, 0.7]

# %%
betas
# Out:
# [0.01, 0.05, 0.25, 1.25]

# %%
np.mean(data_per_alpha_beta[(0.7,0.01)])
# Out:
# np.float64(0.16061282790572945)

# %%
np.mean([x for x in data_per_alpha_beta[(0.7,0.01)] if not np.isnan(x)])
# Out:
# np.float64(0.16061282790572945)

# %%
[5**i*0.01 for i in range(4)]
# Out:
# [0.01, 0.05, 0.25, 1.25]

# %%
ls
# Out:
# alpha_beta_fixed_n.pdf       level_k_lgt_generator/
# benchmark_results.csv        rtime_against_ntaxa.py
# benchmark_results_debug.csv  run_distance_computations.py
# big_benchmark_backup.csv     scatter_num_transfer_per_edge_rtime.py
# fixed_n_alpha_beta.ipynb
