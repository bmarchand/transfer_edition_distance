# %%
import asymmetree.treeevolve as te

# %%
from asymmetree.genome import GenomeSimulator

# %%
S = te.species_tree_n(5)

# %%
gs = GenomeSimulator(S)

# %%
gs.simulate_gene_trees(250)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 gs.simulate_gene_trees(250)
#
# File ~/.local/lib/python3.13/site-packages/asymmetree/genome/GenomeSimulation.py:85, in GenomeSimulator.simulate_gene_trees(self, n, **kwargs)
#      68 """Simulate gene trees.
#      69
#      70 Simulates the 'true gene trees' which still contain the loss events as
#    (...)     80     documentation.
#      81 """
#      83 self.number_of_families = n
# ---> 85 self.true_gene_trees = te.gene_trees(self.S, n=n, **kwargs)
#      87 self.pruned_gene_trees = [te.prune_losses(tree)
#      88                           for tree in self.true_gene_trees]
#      90 # sequences should be emptied here if methods were called before
#
# ...
