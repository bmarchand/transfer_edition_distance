# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
d = pd.DataFrame(data=[[0,1,2],[1,0,3],[3,2,0]],columns=["Basic","Sankoff","Genesis"])

# %%
sns.heatmap([[921,489],[0,958]],
            mask=np.array([[False,False],[True,False]]),
            annot=[["921","489"],["0","958"]],
            xticklabels=["Basic","Genesis"],
            yticklabels=["Sankoff","Basic"],
            cbar_kws={'label':"transfer edition distance"})

plt.savefig("heatmap_distance_compact.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.heatmap([[921,489],[0,958]],
#       2             mask=np.array([[False,False],[True,False]]),
#       3             annot=[["921","489"],["0","958"]],
#       4             xticklabels=["Basic","Genesis"],
#       5             yticklabels=["Sankoff","Basic"],
#       6             cbar_kws={'label':"transfer edition distance"})
#       8 plt.savefig("heatmap_distance_compact.pdf")
#
# File ~/meta_rep/postdoc_projects/transfer_edition_distance/ted_env/lib/python3.13/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
# ...
